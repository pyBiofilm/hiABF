# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import (
    accuracy_score,
    cohen_kappa_score,
    roc_auc_score,
    matthews_corrcoef,
    average_precision_score,
)
from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    GradientBoostingClassifier,
    AdaBoostClassifier,
)
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis,
    QuadraticDiscriminantAnalysis,
)
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
import seaborn as sns
from sklearn.manifold import TSNE

# %%
data = pd.read_csv('data.csv')
data=data.dropna(axis = 'columns')
data.shape
y_col=data.iloc[:,2215]
x_col=data.iloc[:,0:-1]
x_train , x_test , y_train , y_test = train_test_split(x_col,y_col, test_size = 0.25 , shuffle = True)
seed = 42
# Data splitting
y_col = data.iloc[:, 2215]
x_col = data.iloc[:, 0:-1]
x_train, x_test, y_train, y_test = train_test_split(
    x_col, y_col, test_size=0.25, shuffle=True
)
# TSNE analysis
m = TSNE(perplexity=5.0, random_state=2, learning_rate=200)
tsne_features = m.fit_transform(x_train.iloc[:, 0:-1])  # Modify the column indices if needed

df = pd.DataFrame(tsne_features, columns=["x", "y"])
df["label"] = y_train.map({1: "ABF", -1: "non-ABF"})  # Map labels to desired names
df = df.sample(frac=1)
plt.figure(figsize=(10, 6), dpi=800,facecolor='white')

# Plot the data points
sns.set_palette(['#DC143C', '#929591'])
palette = {'ABF': '#DC143C', 'non-ABF': '#929591'}

ax = sns.scatterplot(x="x", y="y", hue="label", data=df, marker='o', s=300, alpha=1.0)

# Add labels and title
plt.xlabel("Dimension 1", fontweight='bold', fontsize=20)
plt.xticks(fontsize=20, fontweight='bold')
plt.ylabel("Dimension 2", fontweight='bold', fontsize=20)
plt.yticks(fontsize=20, fontweight='bold')
plt.title("TSNE Analysis", fontweight='bold', fontsize=20)
ax = plt.gca()
ax.spines['bottom'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
# Adjust plot settings for better resolution
plt.tight_layout()
# plt.savefig("tsne_plot.png", dpi=300)  # Set dpi to desired resolution (e.g., 300)

# Show the plot
plt.show()
# Out:
# C:\Users\user\AppData\Roaming\Python\Python38\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
